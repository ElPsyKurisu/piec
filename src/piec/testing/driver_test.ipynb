# %%
#test
from piec.drivers.autodetect import autodetect
from piec.drivers.utilities import PiecManager

# %%
scope = autodetect("scope")
# Out:
# Autodetect: Scanning for instrument of type Oscilloscope...
#   -> Checking GPIB0::7::INSTR...
# Autodetect: Probing GPIB0::7::INSTR...
#   -> IDN: AGILENT TECHNOLOGIES,DSO-X 3024A,MY63080078,02.65.2021030741
#   -> Loading driver: piec.drivers.oscilloscope.k_dsox3024a.KeysightDSOX3024a
#   -> MATCH: GPIB0::7::INSTR is a Oscilloscope!

# %%
awg = autodetect("awg")
# Out:
# Autodetect: Scanning for instrument of type Awg...
#   -> Checking GPIB0::7::INSTR...
# Autodetect: Probing GPIB0::7::INSTR...
#   -> IDN: AGILENT TECHNOLOGIES,DSO-X 3024A,MY63080078,02.65.2021030741
#   -> Loading driver: piec.drivers.oscilloscope.k_dsox3024a.KeysightDSOX3024a
#   -> Checking GPIB0::8::INSTR...
# Autodetect: Probing GPIB0::8::INSTR...
#   -> IDN: Agilent Technologies,81150A,MY53821602,3.0.0.0-4.6
#   -> Loading driver: piec.drivers.example.specific_example.AnnotatedAwgDriver
# No instrument of type Awg found.

# %%
pm = PiecManager()

# %%
pm.list_resources()
# Out:
# ('GPIB0::7::INSTR', 'GPIB0::8::INSTR')

# %%
awg = autodetect("GPIB0::8::INSTR")
# Out:
# Autodetect: Probing GPIB0::8::INSTR...
#   -> IDN: Agilent Technologies,81150A,MY53821602,3.0.0.0-4.6
#   -> Loading driver: piec.drivers.example.specific_example.AnnotatedAwgDriver
